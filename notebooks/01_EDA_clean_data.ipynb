# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Φόρτωση του clean_data.csv
df = pd.read_csv("../data/clean_data.csv")

# Προβολή των πρώτων 5 γραμμών
df.head()
# Out:
#       name        age   salary
# 0  Γιάννης  30.000000  50000.0
# 1     Άννα  31.666667  55000.0
# 2  Μιχάλης  40.000000  60000.0
# 3    Σοφία  25.000000  55000.0

# %%
# Στατιστικά περιγραφικά στοιχεία
df.describe(include='all')
# Out:
#            name        age        salary
# count         4   4.000000      4.000000
# unique        4        NaN           NaN
# top     Γιάννης        NaN           NaN
# freq          1        NaN           NaN
# mean        NaN  31.666667  55000.000000
# std         NaN   6.236096   4082.482905
# min         NaN  25.000000  50000.000000
# 25%         NaN  28.750000  53750.000000
# 50%         NaN  30.833333  55000.000000
# 75%         NaN  33.750000  56250.000000
# max         NaN  40.000000  60000.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['salary'], bins=10, kde=True)
plt.title("Κατανομή μισθών")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="age", y="salary", hue="name")
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
